# %% [markdown]
# #  importing dataset

# %%
import seaborn as sns
from matplotlib import pyplot as plt
fmri = sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %% [markdown]
# ###  Seaborn Line plot

# %%
sns.lineplot(x="timepoint",y="signal",data=fmri)
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %% [markdown]
# ##  Seaborn Bar plot

# %%
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd

sns.set(style = 'whitegrid')
iris=pd.read_csv('IRIS.csv')
sns.barplot(x='petal_length',y='sepal_length',palette="Blues_d",data=iris)
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>

# %% [markdown]
# ## Scatter Plot

# %%
sns.scatterplot(x="sepal_length",y="petal_length",data=iris)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# ## Seaborn Histogram

# %%
sns.distplot(iris['sepal_width'])
# Out:
# C:\Users\subha\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sepal_width', ylabel='Density'>

# %% [markdown]
# ## Seaborn Joint plot

# %%
sns.jointplot(x='sepal_length',y='petal_length', data=iris)

# %% [markdown]
# ## seaborn Box plot

# %%
sns.boxplot(x='petal_length',y='sepal_length',data=iris)
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>

# %%
#pie plot
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ##  violin plot

# %%
sns.violinplot(y = iris['sepal_length'], x = iris['sepal_width'])
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>

# %% [markdown]
# ##  pair plot

# %%
sns.pairplot(iris)

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
dataset = sns.load_dataset('fmri')

import warnings
# warnings.filterwarnings('fmri')
dataset.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
dataset.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
dataset.describe()
# Out:
#          timepoint       signal
# count  1064.000000  1064.000000
# mean      9.000000     0.003540
# std       5.479801     0.093930
# min       0.000000    -0.255486
# 25%       4.000000    -0.046070
# 50%       9.000000    -0.013653
# 75%      14.000000     0.024293
# max      18.000000     0.564985

# %%
dataset.plot(x='timepoint', y='signal',style='*', c="r")
plt.title("Time&signal")
# Out:
# Text(0.5, 1.0, 'Time&signal')

# %%
sns.barplot(x='timepoint', y='signal',data=fmri)
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
sns.pairplot(data=fmri)

# %%
# sns.pieplot(data=fmri)

# %%
dataset
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.scatterplot(y='timepoint', x='signal',hue='timepoint',data=fmri)
# Out:
# <AxesSubplot:xlabel='signal', ylabel='timepoint'>

# %%
dataset['region'].replace(['parietal', 'frontal'],[0, 1], inplace=True)
# dataset['event'].replace(['stim', 'cue'],[0, 1], inplace=True)

# %%
dataset
# Out:
#      subject  timepoint  event  region    signal
# 0        s13         18      0       0 -0.017552
# 1         s5         14      0       0 -0.080883
# 2        s12         18      0       0 -0.081033
# 3        s11         18      0       0 -0.046134
# 4        s10         18      0       0 -0.037970
# ...      ...        ...    ...     ...       ...
# 1059      s0          8      1       1  0.018165
# 1060     s13          7      1       1 -0.029130
# 1061     s12          7      1       1 -0.004939
# 1062     s11          7      1       1 -0.025367
# 1063      s0          0      1       0 -0.006899
#
# [1064 rows x 5 columns]

# %%
# df.drop(['A'], axis=1)

# %%
# prepare my dataset
# x = dataset.iloc[:,:-1]
x = dataset.iloc[:,2:]
y=dataset.iloc[:,1]

# %%
x.head()
# Out:
#    event  region    signal
# 0      0       0 -0.017552
# 1      0       0 -0.080883
# 2      0       0 -0.081033
# 3      0       0 -0.046134
# 4      0       0 -0.037970

# %%
x.shape
# Out:
# (1064, 3)

# %%
y.shape
# Out:
# (1064,)

# %%
y.head()
# Out:
# 0    18
# 1    14
# 2    18
# 3    18
# 4    18
# Name: timepoint, dtype: int64

# %%
# train & test TTS
from sklearn.model_selection import train_test_split
# x,y = np.arrange
x_train,x_test,y_train,y_test = train_test_split(x, y, random_state=0, train_size = .75)

# %%
# y_pred=regressor.predict(x_test)
# y_pred

# %%
x_test.head()
# Out:
#      event  region    signal
# 175      0       0  0.221493
# 986      1       1 -0.012496
# 686      1       1  0.011241
# 521      0       0 -0.039327
# 856      1       0 -0.021824

# %%
y_test.head()
# Out:
# 175     6
# 986     2
# 686    15
# 521     0
# 856    14
# Name: timepoint, dtype: int64

# %%
x_train.head()
# Out:
#      event  region    signal
# 664      1       1  0.010535
# 37       0       0 -0.064138
# 975      1       1  0.025693
# 158      0       0  0.238231
# 40       0       0 -0.064998

# %%
y_train.head()
# Out:
# 664    14
# 37     16
# 975     3
# 158     7
# 40     16
# Name: timepoint, dtype: int64

# %%
import pandas as pd
df = pd.DataFrame({
    'Actual':y_test,
    'Predict':y_train
})
df
# Out:
#       Actual  Predict
# 0        NaN     18.0
# 1       14.0      NaN
# 2       18.0      NaN
# 3        NaN     18.0
# 4        NaN     18.0
# ...      ...      ...
# 1059     NaN      8.0
# 1060     NaN      7.0
# 1061     7.0      NaN
# 1062     NaN      7.0
# 1063     NaN      0.0
#
# [1064 rows x 2 columns]

# %%
# create model using sketlearn  
from sklearn.linear_model import LinearRegression  
regressor= LinearRegression()  
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred= regressor.predict(x_test)  
x_pred= regressor.predict(x_train)

# %%
# plt.scatter(y_pred, x_pred)

# %%
x_pred.shape
# Out:
# (798,)

# %%
x_test.shape
# Out:
# (266, 3)

# %%
x_train.shape
# Out:
# (798, 3)

# %%
y_test.shape
# Out:
# (266,)

# %%
y_train.shape
# Out:
# (798,)

# %%
plt.scatter(x_pred, y_train)

# %%
plt.bar(x_pred,y_train)
# Out:
# <BarContainer object of 798 artists>

# %%
# from sklearn.metrics import r2_score
# r2_score(y_test,y_pred)

# %%
# from sklearn.metrics import r2_score
# r2_score(x_pred,y_train)

# %%
from sklearn.metrics import r2_score
r2_score(y_train,x_pred)
# Out:
# 0.08712432523960689

# %%
# from sklearn.metrics import r2_score
# r2_score(y_pred,y_test)
